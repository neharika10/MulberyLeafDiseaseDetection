# %% [markdown]
# <a href="https://colab.research.google.com/github/neharika10/MulberyLeafDiseaseDetection/blob/main/yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.5/605.5 kB 9.4 MB/s eta 0:00:00
# ...

# %%
import tensorflow as tf

# %%
device_list= tf.test.gpu_device_name()

# %%
device_list
# Out:
# '/device:GPU:0'

# %%
if device_list!= '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_list))
# Out:
# Found GPU at: /device:GPU:0

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.5/605.5 kB 32.3 MB/s eta 0:00:00
# ...

# %%
train='/content/drive/MyDrive/yolo/datasets/train'
val='/content/drive/MyDrive/yolo/datasets/val'
data_custom='/content/drive/MyDrive/yolo/data_custom.yaml'

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.3/78.2 GB disk)

# %%
# !yolo train model=yolov8n.pt data='/content/drive/MyDrive/yolo/data_custom.yaml' epochs=100 imgsz=640 batch=8
# Out:
# Ultralytics YOLOv8.0.137 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode= predict model=yolo8_custom.pt conf=0.5 source='/content/a.jpg'
# Out:
# Ultralytics YOLOv8.0.137 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/a.jpg: 448x640 1 sootyMould, 60.8ms
# Speed: 3.6ms preprocess, 60.8ms inference, 88.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict5
